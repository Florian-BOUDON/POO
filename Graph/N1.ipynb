# %%
from Graph import Graphiques

# %%
import pandas as pd
df=pd.read_csv("df_model.csv",sep=";")
df=df.sample(frac=0.01)
df.drop(columns=["Unnamed: 0"],inplace=True)
df
# Out:
#         height(cm)  Gtp  hemoglobin  triglyceride  Cholesterol  \
# 28999          170   18        14.8            53          151
# 138599         170   66        16.3           208          210
# 89595          145   23        13.3            27          200
# 67983          165   13        11.1           100          223
# 7743           160   29        15.5            75          219
# ...            ...  ...         ...           ...          ...
# 134842         160   12        11.6            28          200
# 27043          165   28        14.6            88          235
# 122713         165   16        14.4           132          189
# 75320          155   19        11.7           144          178
# 16668          150   18        12.3            99          215
#
#         fasting blood sugar  systolic  HDL  ALT  AST  smoking
# 28999                    89       128   69   14   17        0
# 138599                   94       128   39   40   24        1
# ...

# %%
graph=Graphiques(df)
graph.camembert(column="smoking",title="Smoking")

# %%
graph.histogramme_simple(x="smoking",y="Gtp")

# %%
graph.histogramme_stratifie(target="smoking")

# %%
graph.valeurs_manquantes()

# %%
graph.parallele_coordinates(target="smoking",sample_frac=1)

# %%
graph.heatmap_corr()

# %%
help(graph)
# Out:
# Help on Graphiques in module Graph object:
#
# class Graphiques(builtins.object)
#  |  Graphiques(df)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, df)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  camembert(self, column, title='', figsize=(6, 6), colors=None)
#  |
#  |  courbe_moyenne_mobile(self, column, window=8, resample='W', title='', figsize=(14, 8))
#  |
#  |  heatmap_corr(self, method='pearson', figsize=(12, 11))
#  |
#  |  histogramme_numerique(self, title='', figsize=(14, 12))
#  |
#  |  histogramme_simple(self, x, y, title='', figsize=(8, 3), color='r')
#  |
#  |  histogramme_stratifie(self, target, title='', figsize=(16, 16))
#  |
#  |  paireplot(self, target=None, sample_frac=0.01)
#  |
#  |  parallele_coordinates(self, target, sample_frac=0.01)
#  |
#  |  valeurs_manquantes(self)
#  |
#  |  valeurs_manquantes_par_colonne(self, long=10)
#  |
#  |  ----------------------------------------------------------------------
# ...
